# %%
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import os
import shutil
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import StratifiedShuffleSplit
import pickle

# %%
# def time_start(name_file):
#     file_tsv = name_file[:-3]+'tsv'
#     # Đọc tệp TSV bằng pandas
#     # print(file_tsv)
#     df = pd.read_csv(file_tsv, delimiter='\t')
#     df=df.iloc
#     df0 = df[:,0]
#     df2 = df[:,2]
#     for i in range(len(df2)):
#         if(df2[i]==1):
#             time = df0[i]
#             break
#     return df0[i]

# %%
### Chia file.wav ra moi folder

# data = 'training_data'

# out_file = 'training_data_all/'
# for file in os.listdir(data):
#     if(file.endswith(".wav") == True):

#         name_file = os.path.join(data,file)
#         time_begin = (time_start(name_file))
#         file_txt = (name_file.split('_')[0])+'_'+(name_file.split('_')[1])+'.txt'
#         # print(file_txt)
#         df = pd.read_csv(file_txt)
#         df=np.array(df)
#         # print(df)
#         if (df == '#Murmur: Absent').any().any():
#             # print('Absent')
#             shutil.copy(name_file, out_file +'Absent/'+str(time_begin)+'_'+file)
#         elif (df == '#Murmur: Present').any().any():
#             # print('Present')
#             shutil.copy(name_file, out_file +'Present/'+str(time_begin)+'_'+file)
#         elif (df == '#Murmur: Unknown').any().any():
#             # print('Unknown')
#             shutil.copy(name_file, out_file +'Unknown/'+str(time_begin)+'_'+file)

# %%
""" 
/training_data_all
        --->Unknown
        --->Absent
        --->Present
"""
# Out:
# ' \n/training_data_all\n        --->Unknown\n        --->Absent\n        --->Present\n'

# %%
def show_spectrogram (file,n_fft,n_mels,hop_lenght):
    audio, sr = librosa.load(file,sr=4000)
    audio = audio[:sr*5]
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr,n_fft= n_fft ,n_mels=n_mels,hop_length=hop_lenght)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram ,ref=np.max)

    fig, ax = plt.subplots(figsize=(5,2))
    a =librosa.display.specshow(mel_spectrogram_db,
                            x_axis='time',
                            y_axis='linear',
                            sr=sr,
                            hop_length=512,
                            )
    plt.title("Audio Spectrogram Representation")
    plt.colorbar(format='%+2.0f dB')
    plt.xlabel("Time(s)")
    plt.ylabel("Frequency (Hz)")
    plt.show()

# %%
def show (n_fft  ,n_mels,hop_lenght):
    audio_file_absent = "training_data_all/Absent/0.04025_49970_MV.wav"
    audio_file_present = "training_data_all/Present/0.08025_68255_TV.wav"
    audio_file_unknown = "training_data_all/Unknown/0.83_85081_MV.wav"
    show_spectrogram(audio_file_absent,n_fft= n_fft ,n_mels=n_mels,hop_lenght=hop_lenght)
    show_spectrogram(audio_file_present,n_fft= n_fft ,n_mels=n_mels,hop_lenght=hop_lenght)
    show_spectrogram(audio_file_unknown,n_fft= n_fft ,n_mels=n_mels,hop_lenght=hop_lenght)
show(n_fft = 128 ,n_mels=64,hop_lenght=512)

# %%
# data_train = 'training_data_all'
# data_time = []
# for folders in os.listdir(data_train):
#     print(folders)
#     name_folders = os.path.join(data_train,folders)
#     for file in os.listdir(name_folders):
#         name_files = os.path.join(name_folders,file)
#         y,sr = librosa.load(name_files,sr=4000)
#         audio_duration = (len(y)/sr)
#         data_time.append(audio_duration)

# np.min(data_time)

# %%
def create_data (audio,file,sr):
    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr,n_fft= 128 ,n_mels=64,hop_length=300)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram ,ref=np.max)
    # mel_spectrogram_db = mel_spectrogram_db.reshape([128,128,1])
    x_data.append(mel_spectrogram_db)

# %%
def split_audio(name_files,file,time_limit,sr):
    audio, sr = librosa.load(name_files, sr=sr)
    file = file[:-4]
    segment_length = time_limit * sr
    num_segments = (len(audio) // segment_length)
    for i in range(num_segments):
        start_sample = i * segment_length
        end_sample = (i + 1) * segment_length

        segment = audio[start_sample:end_sample]
        create_data(segment,file,sr)
        label = name_files.split('/')[1]
        get_label(label)

# %%
def get_label(label):
    # print(folders)
    y_data.append(label)

# %%
def get_date(name_files,file,time_limit,sr = 4000):
    # print(name_files)
    split_audio(name_files,file,time_limit,sr)

# %%
data_train = 'training_data_all'
x_data = []
y_data = []
for folders in os.listdir(data_train):
    print(folders)
    name_folders = os.path.join(data_train,folders)
    for file in os.listdir(name_folders):
        name_files = os.path.join(name_folders,file)
        get_date(name_files,file,time_limit = 2,sr = 4000)


file = open('data_file.csv','wb')
pickle.dump((x_data,y_data),file)
file.close()
# Out:
# Unknown
# Absent
# Present

# %%
file = open('data_file.csv', 'rb')
data = pickle.load(file)
x_data,y_data =data
file.close()
x_data=np.array(x_data)
y_data = np.array(y_data)

# %%
from collections import Counter

counters = Counter(y_data)

for value, count in counters.items():
    print(f"{value} xuất hiện {count}")
# Out:
# Unknown xuất hiện 1662
# Absent xuất hiện 26348
# Present xuất hiện 6548

# %%
x_data=np.array(x_data)
y_data=np.array(y_data)
print(x_data.shape)
print(y_data.shape)
# Out:
# (34558, 64, 27)
# (34558,)

# %%
x_test = []
y_test = []
x_train = []
y_train = []

# %%
encoder = LabelBinarizer()
y_data=encoder.fit_transform(y_data)


# Sử dụng StratifiedShuffleSplit để chia dữ liệu theo tỷ lệ
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=68)

# Lặp qua các chỉ số của tập huấn luyện và tập kiểm tra
for train_index, test_index in sss.split(x_data, y_data):
    x_train, x_test = x_data[train_index], x_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]

# %%
input_shape = x_test[1].shape
print(input_shape)
# Out:
# (64, 27)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, BatchNormalization, LSTM, Dense, Dropout,Flatten
from tensorflow.keras.callbacks import ModelCheckpoint

model = Sequential()

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=input_shape))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))


model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))


model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(LSTM(128,return_sequences=True))
model.add(LSTM(64, return_sequences=False))  

model.add(Flatten())
model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.5))

model.add(Dense(3, activation='softmax')) 


model.compile(optimizer='adam', loss='MSE', metrics=['accuracy'])

model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_54 (Conv1D)          (None, 64, 64)            8704
#
#  max_pooling1d_54 (MaxPooli  (None, 32, 64)            0
#  ng1D)
#
#  conv1d_55 (Conv1D)          (None, 32, 128)           41088
#
#  max_pooling1d_55 (MaxPooli  (None, 16, 128)           0
#  ng1D)
#
#  conv1d_56 (Conv1D)          (None, 16, 256)           164096
#
#  max_pooling1d_56 (MaxPooli  (None, 8, 256)            0
#  ng1D)
#
#  batch_normalization_16 (Ba  (None, 8, 256)            1024
#  tchNormalization)
#
#  lstm_33 (LSTM)              (None, 8, 128)            197120
#
#  lstm_34 (LSTM)              (None, 64)                49408
#
#  flatten_11 (Flatten)        (None, 64)                0
#
#  dense_45 (Dense)            (None, 64)                4160
#
#  dense_46 (Dense)            (None, 32)                2080
#
#  dense_47 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 467779 (1.78 MB)
# Trainable params: 467267 (1.78 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,batch_size=64, epochs=50,validation_data=(x_test, y_test), callbacks=[model_checkpoint])
# Out:
# Epoch 1/50
# 2023-10-30 12:49:09.302816: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 167201280 exceeds 10% of free system memory.
# 378/378 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.7652
# Epoch 1: val_accuracy improved from -inf to 0.61159, saving model to best_model.h5
# 378/378 [==============================] - 8s 11ms/step - loss: 0.1233 - accuracy: 0.7652 - val_loss: 0.1728 - val_accuracy: 0.6116
# Epoch 2/50
#  15/378 [>.............................] - ETA: 2s - loss: 0.1199 - accuracy: 0.7646
# /home/duyphuoc/Desktop/heart_sound_new/venv/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 374/378 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.7763
# Epoch 2: val_accuracy improved from 0.61159 to 0.73582, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1174 - accuracy: 0.7760 - val_loss: 0.1279 - val_accuracy: 0.7358
# Epoch 3/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.1092 - accuracy: 0.7955
# Epoch 3: val_accuracy did not improve from 0.73582
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1094 - accuracy: 0.7950 - val_loss: 0.1513 - val_accuracy: 0.6883
# Epoch 4/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.7983
# Epoch 4: val_accuracy improved from 0.73582 to 0.78713, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1071 - accuracy: 0.7982 - val_loss: 0.1121 - val_accuracy: 0.7871
# Epoch 5/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.8030
# Epoch 5: val_accuracy improved from 0.78713 to 0.80295, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1044 - accuracy: 0.8030 - val_loss: 0.1048 - val_accuracy: 0.8030
# Epoch 6/50
# 378/378 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.8064
# Epoch 6: val_accuracy improved from 0.80295 to 0.80469, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1032 - accuracy: 0.8064 - val_loss: 0.1039 - val_accuracy: 0.8047
# Epoch 7/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.8073
# Epoch 7: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1018 - accuracy: 0.8077 - val_loss: 0.1086 - val_accuracy: 0.7921
# Epoch 8/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.8091
# Epoch 8: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1011 - accuracy: 0.8090 - val_loss: 0.1093 - val_accuracy: 0.7906
# Epoch 9/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.1007 - accuracy: 0.8091
# Epoch 9: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.1004 - accuracy: 0.8096 - val_loss: 0.1055 - val_accuracy: 0.8011
# Epoch 10/50
# 378/378 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.8126
# Epoch 10: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0994 - accuracy: 0.8126 - val_loss: 0.1077 - val_accuracy: 0.7942
# Epoch 11/50
# 371/378 [============================>.] - ETA: 0s - loss: 0.0982 - accuracy: 0.8120
# Epoch 11: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0981 - accuracy: 0.8121 - val_loss: 0.1311 - val_accuracy: 0.7394
# Epoch 12/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.8147
# Epoch 12: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0973 - accuracy: 0.8143 - val_loss: 0.1064 - val_accuracy: 0.7963
# Epoch 13/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.8173
# Epoch 13: val_accuracy did not improve from 0.80469
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0966 - accuracy: 0.8174 - val_loss: 0.1034 - val_accuracy: 0.8047
# Epoch 14/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.8164
# Epoch 14: val_accuracy improved from 0.80469 to 0.80536, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0964 - accuracy: 0.8168 - val_loss: 0.1022 - val_accuracy: 0.8054
# Epoch 15/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.8171
# Epoch 15: val_accuracy improved from 0.80536 to 0.80671, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0965 - accuracy: 0.8172 - val_loss: 0.1017 - val_accuracy: 0.8067
# Epoch 16/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.0945 - accuracy: 0.8186
# Epoch 16: val_accuracy improved from 0.80671 to 0.80874, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0945 - accuracy: 0.8187 - val_loss: 0.1031 - val_accuracy: 0.8087
# Epoch 17/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0932 - accuracy: 0.8232
# Epoch 17: val_accuracy did not improve from 0.80874
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0933 - accuracy: 0.8228 - val_loss: 0.1003 - val_accuracy: 0.8085
# Epoch 18/50
# 378/378 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.8224
# Epoch 18: val_accuracy did not improve from 0.80874
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0930 - accuracy: 0.8224 - val_loss: 0.1059 - val_accuracy: 0.8036
# Epoch 19/50
# 377/378 [============================>.] - ETA: 0s - loss: 0.0915 - accuracy: 0.8256
# Epoch 19: val_accuracy did not improve from 0.80874
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0915 - accuracy: 0.8256 - val_loss: 0.1028 - val_accuracy: 0.8036
# Epoch 20/50
# 378/378 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.8260
# Epoch 20: val_accuracy did not improve from 0.80874
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0913 - accuracy: 0.8260 - val_loss: 0.1024 - val_accuracy: 0.8021
# Epoch 21/50
# 371/378 [============================>.] - ETA: 0s - loss: 0.0900 - accuracy: 0.8283
# Epoch 21: val_accuracy did not improve from 0.80874
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0901 - accuracy: 0.8281 - val_loss: 0.1091 - val_accuracy: 0.7907
# Epoch 22/50
# 372/378 [============================>.] - ETA: 0s - loss: 0.0887 - accuracy: 0.8316
# Epoch 22: val_accuracy improved from 0.80874 to 0.81173, saving model to best_model.h5
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0887 - accuracy: 0.8317 - val_loss: 0.0999 - val_accuracy: 0.8117
# Epoch 23/50
# 378/378 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.8358
# Epoch 23: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0869 - accuracy: 0.8358 - val_loss: 0.1001 - val_accuracy: 0.8103
# Epoch 24/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.0863 - accuracy: 0.8371
# Epoch 24: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0864 - accuracy: 0.8370 - val_loss: 0.1037 - val_accuracy: 0.8017
# Epoch 25/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.8377
# Epoch 25: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0852 - accuracy: 0.8377 - val_loss: 0.1022 - val_accuracy: 0.8079
# Epoch 26/50
# 372/378 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.8422
# Epoch 26: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0840 - accuracy: 0.8419 - val_loss: 0.1112 - val_accuracy: 0.7802
# Epoch 27/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.8420
# Epoch 27: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0822 - accuracy: 0.8425 - val_loss: 0.1017 - val_accuracy: 0.8057
# Epoch 28/50
# 378/378 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.8480
# Epoch 28: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0803 - accuracy: 0.8480 - val_loss: 0.1014 - val_accuracy: 0.8076
# Epoch 29/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0793 - accuracy: 0.8499
# Epoch 29: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0791 - accuracy: 0.8502 - val_loss: 0.1188 - val_accuracy: 0.7686
# Epoch 30/50
# 375/378 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.8570
# Epoch 30: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0759 - accuracy: 0.8571 - val_loss: 0.1008 - val_accuracy: 0.8083
# Epoch 31/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.8578
# Epoch 31: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0756 - accuracy: 0.8575 - val_loss: 0.1080 - val_accuracy: 0.7916
# Epoch 32/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.8618
# Epoch 32: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0737 - accuracy: 0.8615 - val_loss: 0.1136 - val_accuracy: 0.7834
# Epoch 33/50
# 372/378 [============================>.] - ETA: 0s - loss: 0.0720 - accuracy: 0.8644
# Epoch 33: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0718 - accuracy: 0.8647 - val_loss: 0.1051 - val_accuracy: 0.8047
# Epoch 34/50
# 371/378 [============================>.] - ETA: 0s - loss: 0.0708 - accuracy: 0.8649
# Epoch 34: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0710 - accuracy: 0.8649 - val_loss: 0.1059 - val_accuracy: 0.7998
# Epoch 35/50
# 372/378 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.8718
# Epoch 35: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0681 - accuracy: 0.8715 - val_loss: 0.1133 - val_accuracy: 0.7835
# Epoch 36/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.8754
# Epoch 36: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0661 - accuracy: 0.8753 - val_loss: 0.1093 - val_accuracy: 0.7962
# Epoch 37/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0651 - accuracy: 0.8788
# Epoch 37: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0649 - accuracy: 0.8791 - val_loss: 0.1062 - val_accuracy: 0.8052
# Epoch 38/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.8830
# Epoch 38: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0626 - accuracy: 0.8829 - val_loss: 0.1061 - val_accuracy: 0.8062
# Epoch 39/50
# 371/378 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.8825
# Epoch 39: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0623 - accuracy: 0.8822 - val_loss: 0.1072 - val_accuracy: 0.8015
# Epoch 40/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.0590 - accuracy: 0.8898
# Epoch 40: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0589 - accuracy: 0.8900 - val_loss: 0.1060 - val_accuracy: 0.8059
# Epoch 41/50
# 377/378 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.8918
# Epoch 41: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0578 - accuracy: 0.8917 - val_loss: 0.1135 - val_accuracy: 0.8002
# Epoch 42/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.8948
# Epoch 42: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0562 - accuracy: 0.8947 - val_loss: 0.1103 - val_accuracy: 0.8011
# Epoch 43/50
# 373/378 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.8993
# Epoch 43: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0545 - accuracy: 0.8995 - val_loss: 0.1146 - val_accuracy: 0.7940
# Epoch 44/50
# 374/378 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9011
# Epoch 44: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0532 - accuracy: 0.9012 - val_loss: 0.1106 - val_accuracy: 0.8066
# Epoch 45/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9047
# Epoch 45: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0512 - accuracy: 0.9046 - val_loss: 0.1152 - val_accuracy: 0.7872
# Epoch 46/50
# 377/378 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9116
# Epoch 46: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0479 - accuracy: 0.9116 - val_loss: 0.1176 - val_accuracy: 0.7900
# Epoch 47/50
# 377/378 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9122
# Epoch 47: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0469 - accuracy: 0.9123 - val_loss: 0.1123 - val_accuracy: 0.7995
# Epoch 48/50
# 377/378 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9165
# Epoch 48: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0455 - accuracy: 0.9165 - val_loss: 0.1157 - val_accuracy: 0.7995
# Epoch 49/50
# 372/378 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9169
# Epoch 49: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0445 - accuracy: 0.9167 - val_loss: 0.1203 - val_accuracy: 0.7763
# Epoch 50/50
# 376/378 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9201
# Epoch 50: val_accuracy did not improve from 0.81173
# 378/378 [==============================] - 3s 8ms/step - loss: 0.0437 - accuracy: 0.9203 - val_loss: 0.1194 - val_accuracy: 0.7834
